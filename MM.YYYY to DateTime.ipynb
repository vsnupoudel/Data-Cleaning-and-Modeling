# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **Read csv**

# %%
df = pd.read_csv('table.csv')

# %%
df.dtypes
# Out:
# Name                                      object
# Station                                   object
# Time                                     float64
# Homogeniserd mean temperature (month)    float64
# dtype: object

# %% [markdown]
# **Adding zeros to the Year so that the last zero is not missing**

# %%
df['Time'] = df.Time.map('{:.4f}'.format)

# %%
df.dtypes
# Out:
# Name                                      object
# Station                                   object
# Time                                      object
# Homogeniserd mean temperature (month)    float64
# dtype: object

# %%
# i = 48.1
# print(  '{:.4f}'.format(i))

# %%
df.tail(6)
# Out:
#                  Name  Station    Time  Homogeniserd mean temperature (month)
# 2470  Oslo - Blindern  SN18700  2.2020                                    1.9
# 2471  Oslo - Blindern  SN18700  3.2020                                    3.0
# 2472  Oslo - Blindern  SN18700  4.2020                                    7.3
# 2473  Oslo - Blindern  SN18700  5.2020                                   10.2
# 2474  Oslo - Blindern  SN18700  6.2020                                   18.8
# 2475  Oslo - Blindern  SN18700  7.2020                                   15.1

# %%
df['DateTime'] = pd.to_datetime( df['Time'], format= '%m.%Y' )

# %%
df.dtypes
# Out:
# Name                                             object
# Station                                          object
# Time                                             object
# Homogeniserd mean temperature (month)           float64
# DateTime                                 datetime64[ns]
# dtype: object

# %%
plt.figure(figsize=(15,4))
plt.plot(df['DateTime'], df['Homogeniserd mean temperature (month)'])
